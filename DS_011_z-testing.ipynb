# %%
# Question : A teacher claims that the mean score of students in his class is greater than 82 with a standard deviation of 20
#            If a sample of 81 students was selected with the mean score of 90

# %%
import scipy.stats as st
import numpy as np

# %%
s_x = 90
p_u = 82
p_std = 20
n = 81
ap = 0.05

# %%
z_cal = (s_x - p_u) / (p_std / np.sqrt(n))
z_cal
# Out:
# np.float64(3.5999999999999996)

# %%
z_table = st.norm.ppf(1 - ap)
z_table
# Out:
# np.float64(1.6448536269514722)

# %%
if z_table < z_cal:
    print('ha is right')
else:
    print('h0 is wrong')
# Out:
# ha is right
